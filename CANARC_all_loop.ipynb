# %%
import numpy as np
import rasterio as rs
from rasterio.mask import mask
import requests
from io import BytesIO
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# Function to reproject raster data
def reproject_raster(src, target_crs):
    src_data = src.read(1)  # Read the first band
    dst_data = np.empty(src_data.shape, dtype=np.float32)

    # Perform the reprojection
    reproject(
        source=src_data,
        destination=dst_data,
        src_transform=src.transform,
        src_crs=src.crs,
        dst_transform=src.transform,
        dst_crs=target_crs,
        resampling=Resampling.nearest)

    return dst_data, src.transform, target_crs


# path to shape file:

mask_paths = [ 'CANARC_BS_LancasterSound_Province01.shp','CANARC_BS_LancasterSound_Province02.shp','CANARC_BS_LancasterSound_Province03.shp']
site_path = 'canarc_bs_loc.shp'

mask_names = ['LS_01', 'LS_02', 'LS_03']

# years for processing:

years = ['2013','2014','2015','2016','2017','2018']
process_months = [1,8] #Edit as needed if you want to only process specific months

# Load shape files for the sites
site_path = 'canarc_bs_loc.shp'
site_gpd = gpd.read_file(site_path)


#Start loop to go over years and masks:

for year in years:
    for mask_path, mask_name in zip(mask_paths, mask_names):
        # Load the mask
        mask_gpd = gpd.read_file(mask_path)
        mask_gpd = mask_gpd.to_crs('EPSG:3413')  # Match the projections to the sea ice
        bs_mask = mask_gpd.iloc[0].geometry

        # Initialize a dictionary to store mean values
        mean_values_by_date = {}

 # Initialize a dictionary to store mean values
        mean_values_by_date = {}

        # Assuming non-leap year; adjust February to 29 for leap years.
        months_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        months_str = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']

        # Loop through each month and day:
        
        for month_index, days_in_month in enumerate(months_days):
            month_int = month_index + 1 
            if month_int in process_months: #Will filter for the specified months.
                month_str = months_str[month_index]
            
            for day in range(1, days_in_month + 1):
                date = f'{year}{month_int:02d}{day:02d}'
                url = f'https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/{year}/{month_str}/Arctic3125/asi-AMSR2-n3125-{date}-v5.4.tif'
                print(f'Accessing data for {date}: {url}')

        def reproject_raster(src, target_crs):
        
                # Request and process data for each day
                response = requests.get(url)
                if response.status_code == 200:
                    today_seaice_raw = rs.open(BytesIO(response.content))
                    today_seaice_3995, transform_3995, crs_3995 = reproject_raster(today_seaice_raw, 'EPSG:3995')
        
                    # Apply the masks
                    masked_bs, transform_bs = mask(today_seaice_raw, [bs_mask], pad=False, crop=True, nodata=255)
            
                    # Calculate mean sea ice concentration, excluding land and mask values
                    bs_mean = np.mean(masked_bs[0][(masked_bs[0] != 255) & (masked_bs[0] !=120)] )
        
                    mean_values_by_date[date] = {'bs_mean': bs_mean}
                else:
                    print(f'Failed to download data for {date}')
                    mean_values_by_date[date] = {'bs_mean': np.nan, 'bs_mean': np.nan}


                
                # response = requests.get(url)
                # if response.status_code == 200:
                #     today_seaice_raw = rs.open(BytesIO(response.content))
                #     masked_bs, transform_bs = mask(today_seaice_raw, [bs_mask], pad=False, crop=True, nodata=255)

                #     # Calculate mean sea ice concentration, excluding land (120) and mask(255) values
                #     bs_mean = np.mean(masked_bs[0][(masked_bs[0] != 255) & (masked_bs[0] !=120)])
                #     mean_values_by_date[date] = {'bs_mean': bs_mean}
                # else:
                #     print(f'Failed to download data for {date}')
                #     mean_values_by_date[date] = {'bs_mean': np.nan}

        # Convert the dictionary to a DataFrame and plot
        df = pd.DataFrame.from_dict(mean_values_by_date, orient='index', columns=['bs_mean'])
        df.index = pd.to_datetime(df.index)

        #Save csv:

        csv_path = f'E:/CANARC_All/ice_data/CANARC_BS/LS_poly/CANARC_BS_{year}_{mask_name}_NorthWestPassage_3125Km.csv'
        df.to_csv(csv_path, index=True, index_label='Date')
        print(f'Data saved to {csv_path}')

        #Plot and save ice concentrations:

        plt.figure(figsize=(10, 6))
        plt.plot(df.index, df['bs_mean'], label='Daily mean', marker='o')
        plt.title(f'Daily Sea Ice Concentration in {year} for {mask_name}')
        plt.xlabel('Date')
        plt.ylabel('Mean Sea Ice %')
        plt.legend()
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.savefig(f'E:/CANARC_All/ice_data/CANARC_BS/LS_poly/CANARC_BS_{year}_{mask_name}_MeanIceConcentration.png')
        plt.close()
# Out:
# Accessing data for 20130101: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130101-v5.4.tif
# Accessing data for 20130102: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130102-v5.4.tif
# Accessing data for 20130103: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130103-v5.4.tif
# Accessing data for 20130104: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130104-v5.4.tif
# Accessing data for 20130105: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130105-v5.4.tif
# Accessing data for 20130106: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130106-v5.4.tif
# Accessing data for 20130107: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130107-v5.4.tif
# Accessing data for 20130108: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130108-v5.4.tif
# Accessing data for 20130109: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130109-v5.4.tif
# Accessing data for 20130110: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130110-v5.4.tif
# Accessing data for 20130111: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130111-v5.4.tif
# Accessing data for 20130112: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130112-v5.4.tif
# Accessing data for 20130113: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130113-v5.4.tif
# Accessing data for 20130114: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130114-v5.4.tif
# Accessing data for 20130115: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130115-v5.4.tif
# Accessing data for 20130116: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130116-v5.4.tif
# Accessing data for 20130117: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130117-v5.4.tif
# Accessing data for 20130118: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130118-v5.4.tif
# Accessing data for 20130119: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130119-v5.4.tif
# Accessing data for 20130120: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130120-v5.4.tif
# Accessing data for 20130121: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130121-v5.4.tif
# Accessing data for 20130122: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130122-v5.4.tif
# Accessing data for 20130123: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130123-v5.4.tif
# Accessing data for 20130124: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130124-v5.4.tif
# Accessing data for 20130125: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130125-v5.4.tif
# Accessing data for 20130126: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130126-v5.4.tif
# Accessing data for 20130127: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130127-v5.4.tif
# Accessing data for 20130128: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130128-v5.4.tif
# Accessing data for 20130129: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130129-v5.4.tif
# Accessing data for 20130130: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130130-v5.4.tif
# Accessing data for 20130131: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130131-v5.4.tif
# Accessing data for 20130201: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130201-v5.4.tif
# Accessing data for 20130202: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130202-v5.4.tif
# Accessing data for 20130203: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130203-v5.4.tif
# Accessing data for 20130204: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130204-v5.4.tif
# Accessing data for 20130205: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130205-v5.4.tif
# Accessing data for 20130206: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130206-v5.4.tif
# Accessing data for 20130207: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130207-v5.4.tif
# Accessing data for 20130208: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130208-v5.4.tif
# Accessing data for 20130209: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130209-v5.4.tif
# Accessing data for 20130210: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130210-v5.4.tif
# Accessing data for 20130211: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130211-v5.4.tif
# Accessing data for 20130212: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130212-v5.4.tif
# Accessing data for 20130213: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130213-v5.4.tif
# Accessing data for 20130214: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130214-v5.4.tif
# Accessing data for 20130215: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20
https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131031-v5.4.tif
# Accessing data for 20131101: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131101-v5.4.tif
# Accessing data for 20131102: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131102-v5.4.tif
# Accessing data for 20131103: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131103-v5.4.tif
# Accessing data for 20131104: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131104-v5.4.tif
# Accessing data for 20131105: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131105-v5.4.tif
# Accessing data for 20131106: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131106-v5.4.tif
# Accessing data for 20131107: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131107-v5.4.tif
# Accessing data for 20131108: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131108-v5.4.tif
# Accessing data for 20131109: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131109-v5.4.tif
# Accessing data for 20131110: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131110-v5.4.tif
# Accessing data for 20131111: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131111-v5.4.tif
# Accessing data for 20131112: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131112-v5.4.tif
# Accessing data for 20131113: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131113-v5.4.tif
# Accessing data for 20131114: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131114-v5.4.tif
# Accessing data for 20131115: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131115-v5.4.tif
# Accessing data for 20131116: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131116-v5.4.tif
# Accessing data for 20131117: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131117-v5.4.tif
# Accessing data for 20131118: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131118-v5.4.tif
# Accessing data for 20131119: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131119-v5.4.tif
# Accessing data for 20131120: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131120-v5.4.tif
# Accessing data for 20131121: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131121-v5.4.tif
# Accessing data for 20131122: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/aug/Arctic3125/asi-AMSR2-n3125-20131122-v5.4.tif
# ...
# Accessing data for 20180915: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180915-v5.4.tif
# Accessing data for 20180916: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180916-v5.4.tif
# Accessing data for 20180917: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180917-v5.4.tif
# Accessing data for 20180918: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180918-v5.4.tif
# Accessing data for 20180919: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180919-v5.4.tif
# Accessing data for 20180920: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180920-v5.4.tif
# Accessing data for 20180921: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180921-v5.4.tif
# Accessing data for 20180922: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180922-v5.4.tif
# Accessing data for 20180923: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180923-v5.4.tif
# Accessing data for 20180924: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180924-v5.4.tif
# Accessing data for 20180925: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180925-v5.4.tif
# Accessing data for 20180926: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180926-v5.4.tif
# Accessing data for 20180927: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180927-v5.4.tif
# Accessing data for 20180928: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180928-v5.4.tif
# Accessing data for 20180929: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180929-v5.4.tif
# Accessing data for 20180930: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20180930-v5.4.tif
# Accessing data for 20181001: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181001-v5.4.tif
# Accessing data for 20181002: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181002-v5.4.tif
# Accessing data for 20181003: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181003-v5.4.tif
# Accessing data for 20181004: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181004-v5.4.tif
# Accessing data for 20181005: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181005-v5.4.tif
# Accessing data for 20181006: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181006-v5.4.tif
# Accessing data for 20181007: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181007-v5.4.tif
# Accessing data for 20181008: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181008-v5.4.tif
# Accessing data for 20181009: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181009-v5.4.tif
# Accessing data for 20181010: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181010-v5.4.tif
# Accessing data for 20181011: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181011-v5.4.tif
# Accessing data for 20181012: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181012-v5.4.tif
# Accessing data for 20181013: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181013-v5.4.tif
# Accessing data for 20181014: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181014-v5.4.tif
# Accessing data for 20181015: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181015-v5.4.tif
# Accessing data for 20181016: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181016-v5.4.tif
# Accessing data for 20181017: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181017-v5.4.tif
# Accessing data for 20181018: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181018-v5.4.tif
# Accessing data for 20181019: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181019-v5.4.tif
# Accessing data for 20181020: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181020-v5.4.tif
# Accessing data for 20181021: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181021-v5.4.tif
# Accessing data for 20181022: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181022-v5.4.tif
# Accessing data for 20181023: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181023-v5.4.tif
# Accessing data for 20181024: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181024-v5.4.tif
# Accessing data for 20181025: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181025-v5.4.tif
# Accessing data for 20181026: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181026-v5.4.tif
# Accessing data for 20181027: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181027-v5.4.tif
# Accessing data for 20181028: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181028-v5.4.tif
# Accessing data for 20181029: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181029-v5.4.tif
# Accessing data for 20181030: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181030-v5.4.tif
# Accessing data for 20181031: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181031-v5.4.tif
# Accessing data for 20181101: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181101-v5.4.tif
# Accessing data for 20181102: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181102-v5.4.tif
# Accessing data for 20181103: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181103-v5.4.tif
# Accessing data for 20181104: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181104-v5.4.tif
# Accessing data for 20181105: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181105-v5.4.tif
# Accessing data for 20181106: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181106-v5.4.tif
# Accessing data for 20181107: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181107-v5.4.tif
# Accessing data for 20181108: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181108-v5.4.tif
# Accessing data for 20181109: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181109-v5.4.tif
# Accessing data for 20181110: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181110-v5.4.tif
# Accessing data for 20181111: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181111-v5.4.tif
# Accessing data for 20181112: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181112-v5.4.tif
# Accessing data for 20181113: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181113-v5.4.tif
# Accessing data for 20181114: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181114-v5.4.tif
# Accessing data for 20181115: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181115-v5.4.tif
# Accessing data for 20181116: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181116-v5.4.tif
# Accessing data for 20181117: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181117-v5.4.tif
# Accessing data for 20181118: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181118-v5.4.tif
# Accessing data for 20181119: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181119-v5.4.tif
# Accessing data for 20181120: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181120-v5.4.tif
# Accessing data for 20181121: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181121-v5.4.tif
# Accessing data for 20181122: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181122-v5.4.tif
# Accessing data for 20181123: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181123-v5.4.tif
# Accessing data for 20181124: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181124-v5.4.tif
# Accessing data for 20181125: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181125-v5.4.tif
# Accessing data for 20181126: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181126-v5.4.tif
# Accessing data for 20181127: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181127-v5.4.tif
# Accessing data for 20181128: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181128-v5.4.tif
# Accessing data for 20181129: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181129-v5.4.tif
# Accessing data for 20181130: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181130-v5.4.tif
# Accessing data for 20181201: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181201-v5.4.tif
# Accessing data for 20181202: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181202-v5.4.tif
# Accessing data for 20181203: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181203-v5.4.tif
# Accessing data for 20181204: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181204-v5.4.tif
# Accessing data for 20181205: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181205-v5.4.tif
# Accessing data for 20181206: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181206-v5.4.tif
# Accessing data for 20181207: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181207-v5.4.tif
# Accessing data for 20181208: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181208-v5.4.tif
# Accessing data for 20181209: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181209-v5.4.tif
# Accessing data for 20181210: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181210-v5.4.tif
# Accessing data for 20181211: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181211-v5.4.tif
# Accessing data for 20181212: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181212-v5.4.tif
# Accessing data for 20181213: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181213-v5.4.tif
# Accessing data for 20181214: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181214-v5.4.tif
# Accessing data for 20181215: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181215-v5.4.tif
# Accessing data for 20181216: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181216-v5.4.tif
# Accessing data for 20181217: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181217-v5.4.tif
# Accessing data for 20181218: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181218-v5.4.tif
# Accessing data for 20181219: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181219-v5.4.tif
# Accessing data for 20181220: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181220-v5.4.tif
# Accessing data for 20181221: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181221-v5.4.tif
# Accessing data for 20181222: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181222-v5.4.tif
# Accessing data for 20181223: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181223-v5.4.tif
# Accessing data for 20181224: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181224-v5.4.tif
# Accessing data for 20181225: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181225-v5.4.tif
# Accessing data for 20181226: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181226-v5.4.tif
# Accessing data for 20181227: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181227-v5.4.tif
# Accessing data for 20181228: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181228-v5.4.tif
# Accessing data for 20181229: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181229-v5.4.tif
# Accessing data for 20181230: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181230-v5.4.tif
# Accessing data for 20181231: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2018/aug/Arctic3125/asi-AMSR2-n3125-20181231-v5.4.tif
# Data saved to E:/CANARC_All/ice_data/CANARC_BS/LS_poly/CANARC_BS_2018_LS_03_NorthWestPassage_3125Km.csv

# %%
import numpy as np
import rasterio as rs
from rasterio.mask import mask
import requests
from io import BytesIO
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from rasterio.warp import reproject, Resampling

# Function to reproject raster data
def reproject_raster(src, target_crs):
    src_data = src.read(1)  # Read the first band
    dst_data = np.empty(src_data.shape, dtype=np.float32)
    # Perform the reprojection
    reproject(
        source=src_data,
        destination=dst_data,
        src_transform=src.transform,
        src_crs=src.crs,
        dst_transform=src.transform,
        dst_crs=target_crs,
        resampling=rs.warp.Resampling.nearest)
    return dst_data, src.transform, target_crs

# Define paths and names
mask_paths = ['CANARC_BS_LancasterSound_Province01.shp', 'CANARC_BS_LancasterSound_Province02.shp', 'CANARC_BS_LancasterSound_Province03.shp']
mask_names = ['LS_01', 'LS_02', 'LS_03']
years = ['2013', '2014', '2015', '2016', '2017', '2018']
process_months = [1, 8]

# Load shape files for the sites
site_gpd = gpd.read_file('canarc_bs_loc.shp')

# Loop over years and masks
for year in years:
    for mask_path, mask_name in zip(mask_paths, mask_names):
        mask_gpd = gpd.read_file(mask_path)
        mask_gpd = mask_gpd.to_crs('EPSG:3413')
        bs_mask = mask_gpd.iloc[0].geometry
        mean_values_by_date = {}
        months_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        months_str = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']

        for month_index, days_in_month in enumerate(months_days):
            month_int = month_index + 1
            if month_int in process_months:
                month_str = months_str[month_index]
                for day in range(1, days_in_month + 1):
                    date = f'{year}{month_int:02d}{day:02d}'
                    url = f'https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/{year}/{month_str}/Arctic3125/asi-AMSR2-n3125-{date}-v5.4.tif'
                    print(f'Accessing data for {date}: {url}')
                    response = requests.get(url)
                    if response.status_code == 200:
                        with rs.open(BytesIO(response.content)) as today_seaice_raw:
                            today_seaice_3995, transform_3995, crs_3995 = reproject_raster(today_seaice_raw, 'EPSG:3995')
                            masked_bs, transform_bs = mask(today_seaice_raw, [bs_mask], pad=False, crop=True, nodata=255)
                            bs_mean = np.mean(masked_bs[0][(masked_bs[0] != 255) & (masked_bs[0] != 120)])
                            mean_values_by_date[date] = {'bs_mean': bs_mean}
                    else:
                        print(f'Failed to download data for {date}')
                        mean_values_by_date[date] = {'bs_mean': np.nan}
                        
 # Create DataFrame, save to CSV, and plot
        df = pd.DataFrame.from_dict(mean_values_by_date, orient='index', columns=['bs_mean'])
        df.index = pd.to_datetime(df.index)
        csv_path = f'E:/CANARC_All/ice_data/CANARC_BS/LS_poly/CANARC_BS_{year}_{mask_name}_NorthWestPassage_3125Km.csv'
        df.to_csv(csv_path, index=True, index_label='Date')
        print(f'Data saved to {csv_path}')
        plt.figure(figsize=(10, 6))
        plt.plot(df.index, df['bs_mean'], label='Daily mean', marker='o')
        plt.title(f'Daily Sea Ice Concentration in {year} for {mask_name}')
        plt.xlabel('Date')
        plt.ylabel('Mean Sea Ice %')
        plt.legend()
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.savefig(f'E:/CANARC_All/ice_data/CANARC_BS/LS_poly/CANARC_BS_{year}_{mask_name}_MeanIceConcentration.png')
        plt.close()
# Out:
# Accessing data for 20130101: https://data.seaice.uni-bremen.de/amsr2/asi_daygrid_swath/n3125/2013/jan/Arctic3125/asi-AMSR2-n3125-20130101-v5.4.tif
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 57
#      55 with rs.open(BytesIO(response.content)) as today_seaice_raw:
#      56     today_seaice_3995, transform_3995, crs_3995 = reproject_raster(today_seaice_raw, 'EPSG:3995')
# ---> 57     masked_bs, transform_bs = mask(today_seaice_raw, [bs_mask], pad=False, crop=True, nodata=255)
#      58     bs_mean = np.mean(masked_bs[0][(masked_bs[0] != 255) & (masked_bs[0] != 120)])
#      59     mean_values_by_date[date] = {'bs_mean': bs_mean}
#
# File ~\anaconda3\envs\icefun\Lib\site-packages\rasterio\mask.py:178, in mask(dataset, shapes, all_touched, invert, nodata, filled, crop, pad, pad_width, indexes)
#     175     else:
#     176         nodata = 0
# --> 178 shape_mask, transform, window = raster_geometry_mask(
#     179     dataset, shapes, all_touched=all_touched, invert=invert, crop=crop,
#     180     pad=pad, pad_width=pad_width)
#     182 if indexes is None:
#     183     out_shape = (dataset.count, ) + shape_mask.shape
#
# File ~\anaconda3\envs\icefun\Lib\site-packages\rasterio\mask.py:80, in raster_geometry_mask(dataset, shapes, all_touched, invert, crop, pad, pad_width)
#      77     pad_y = 0
#      79 try:
# ---> 80     window = geometry_window(dataset, shapes, pad_x=pad_x, pad_y=pad_y)
#      82 except WindowError:
#      83     # If shapes do not overlap raster, raise Exception or UserWarning
#      84     # depending on value of crop
#      85     if crop:
#
# File ~\anaconda3\envs\icefun\Lib\site-packages\rasterio\features.py:451, in geometry_window(dataset, shapes, pad_x, pad_y, north_up, rotated, pixel_precision, boundless)
#     403 def geometry_window(
#     404     dataset,
#     405     shapes,
#    (...)
#     411     boundless=False,
#     412 ):
#     413     """Calculate the window within the raster that fits the bounds of
#     414     the geometry plus optional padding.  The window is the outermost
#     415     pixel indices that contain the geometry (floor of offsets, ceiling
#    (...)
#     448
#     449     """
# --> 451     all_bounds = [bounds(shape, transform=~dataset.transform) for shape in shapes]
#     453     cols = [
#     454         x
#     455         for (left, bottom, right, top) in all_bounds
#     456         for x in (left - pad_x, right + pad_x, right + pad_x, left - pad_x)
#     457     ]
#     458     rows = [
#     459         y
#     460         for (left, bottom, right, top) in all_bounds
#     461         for y in (top - pad_y, top - pad_y, bottom + pad_y, bottom + pad_y)
#     462     ]
#
# File ~\anaconda3\envs\icefun\Lib\site-packages\rasterio\features.py:388, in bounds(geometry, north_up, transform)
#     371 """Return a (left, bottom, right, top) bounding box.
#     372
#     373 From Fiona 1.4.8. Modified to return bbox from geometry if available.
#    (...)
#     383     Bounding box: (left, bottom, right, top)
#     384 """
#     386 geometry = getattr(geometry, '__geo_interface__', None) or geometry
# --> 388 if 'bbox' in geometry:
#     389     return tuple(geometry['bbox'])
#     391 geom = geometry.get('geometry') or geometry
#
# TypeError: argument of type 'NoneType' is not iterable
